# %%
f = open("data.txt", 'r')

for i in range(1,1000):
    line = f.readline()
    print line
# Out:
# 2204192	Williamsburg, Brooklyn	DUMBO, Brooklyn	Staten Island Ferry	Brooklyn Bridge	Brooklyn Bridge	Rockfeller Plaza	Rockfeller Plaza	Times Square, New York City	Whitney Museum of American Art	Whitney Museum of American Art	Chelsea Market	The High Line	The High Line	Whitney Museum of American Art	DUMBO, Brooklyn
#
# 431164097	Union Square Greenmarket	Il Corallo Trattoria	Buba Gump Time Square	Blue Bottle Rockefeller Center	MoMA The Museum of Modern Art	MoMA The Museum of Modern Art	MoMA The Museum of Modern Art	MoMA The Museum of Modern Art	MoMA The Museum of Modern Art	Cafe Habana	Chelsea Market	DUMBO, Brooklyn	Times Square, New York City	Statue of Liberty, New York	World Trade Center	Madison Square Park	Times Square, New York City	Bushwick, Brooklyn	Lion King Broadway At Th Minskoff Theatre	Brooklyn Bridge	Brooklyn Bridge	Perry Street Restaurant
#
# ...
